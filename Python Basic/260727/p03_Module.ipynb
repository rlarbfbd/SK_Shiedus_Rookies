# %%
import mod.mod2 as mo2
# Out:
# __name__ mod.mod2
# mod.mod2.py 실행 시작
# mod.mod2.py 실행 종료

# %%
from mod1 import *
# Out:
# __name__ mod1
# mod1.py 실행 시작
# mod1.py 실행 종료

# %%
mo2.PI
# Out:
# 3.14
