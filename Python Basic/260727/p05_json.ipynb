# %% [markdown]
# json

# %%
import json

# %%
# json file -> object

with open("C:\\Users\\EZ\\Desktop\\루키즈\\Python\\Python Basic\\260727\\data.json", "r", encoding="utf-8") as f:
    data_object = json.load(f)

    print(data_object)
    print(type(data_object))
# Out:
# [{'name': 'COOL', 'age': 25}, {'name': 'HOT', 'age': False}]
# <class 'list'>

# %%
data_object
# Out:
# [{'name': 'COOL', 'age': 25}, {'name': 'HOT', 'age': False}]

# %%
# list obj -> str(json)

data_json = json.dumps(data_object)

print(data_json)
print(type(data_json))
# Out:
# [{"name": "COOL", "age": 25}, {"name": "HOT", "age": false}]
# <class 'str'>
